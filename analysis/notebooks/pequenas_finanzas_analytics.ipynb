# %% [markdown]
# # Pequeñas Finanzas — análisis MVP
# Usar sólo exports anonimizados. No subir nombres de niños.

# %%
import pandas as pd
df = pd.read_csv('../samples/demo_learning_events.csv')
df.groupby('game_id')['score'].agg(['count','mean'])
